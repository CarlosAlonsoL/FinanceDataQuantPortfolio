# %% [markdown]
# # Feature exploration
#
# Distributions, correlations and predictive power of features for join/leave labels.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import seaborn as sns
from src.utils.config_loader import load_config

# %%
features_join = pd.read_parquet("data/processed/features_join.parquet")
features_leave = pd.read_parquet("data/processed/features_leave.parquet")

# %%
numeric = features_join.select_dtypes(include="number").columns.tolist()
numeric = [c for c in numeric if c not in ["label_join", "label_leave"]]
features_join[numeric].describe()

# %%
sns.heatmap(features_join[numeric[:10]].corr(), annot=False)
